# %% [markdown]
# # Libraries

# %%
from kornia.color import rgb_to_linear_rgb, rgb_to_xyz, xyz_to_rgb, linear_rgb_to_rgb
import torchvision.datasets
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader
import torchvision.transforms as T
import torch.nn.functional as F
import torchvision.models as models

# %% [markdown]
# # Helper functions

# %%
def rgb_to_lab(image: torch.Tensor) -> torch.Tensor:
    if not isinstance(image, torch.Tensor):
        raise TypeError(f"Input type is not a torch.Tensor. Got {type(image)}")

    if len(image.shape) < 3 or image.shape[-3] != 3:
        raise ValueError(f"Input size must have a shape of (*, 3, H, W). Got {image.shape}")

    # Convert from sRGB to Linear RGB
    lin_rgb = rgb_to_linear_rgb(image)

    xyz_im: torch.Tensor = rgb_to_xyz(lin_rgb)

    # normalize for D65 white point
    xyz_ref_white = torch.tensor([0.95047, 1.0, 1.08883], device=xyz_im.device, dtype=xyz_im.dtype)[..., :, None, None]
    xyz_normalized = torch.div(xyz_im, xyz_ref_white)

    threshold = 0.008856
    power = torch.pow(xyz_normalized.clamp(min=threshold), 1 / 3.0)
    scale = 7.787 * xyz_normalized + 4.0 / 29.0
    xyz_int = torch.where(xyz_normalized > threshold, power, scale)

    x: torch.Tensor = xyz_int[..., 0, :, :]
    y: torch.Tensor = xyz_int[..., 1, :, :]
    z: torch.Tensor = xyz_int[..., 2, :, :]

    L: torch.Tensor = (116.0 * y) - 16.0
    a: torch.Tensor = 500.0 * (x - y)
    _b: torch.Tensor = 200.0 * (y - z)

    out: torch.Tensor = torch.stack([L, a, _b], dim=-3)

    return out

# %%
def lab_to_rgb(L: torch.Tensor, a: torch.Tensor, _b: torch.Tensor, clip: bool = True) -> torch.Tensor:
    # if not isinstance(image, torch.Tensor):
    #     raise TypeError(f"Input type is not a torch.Tensor. Got {type(image)}")
    #
    # if len(image.shape) < 3 or image.shape[-3] != 3:
    #     raise ValueError(f"Input size must have a shape of (*, 3, H, W). Got {image.shape}")

    # L: torch.Tensor = image[..., 0, :, :]
    # a: torch.Tensor = image[..., 1, :, :]
    # _b: torch.Tensor = image[..., 2, :, :]

    fy = (L + 16.0) / 116.0
    fx = (a / 500.0) + fy
    fz = fy - (_b / 200.0)

    # if color data out of range: Z < 0
    fz = fz.clamp(min=0.0)

    fxyz = torch.stack([fx, fy, fz], dim=-3)

    # Convert from Lab to XYZ
    power = torch.pow(fxyz, 3.0)
    scale = (fxyz - 4.0 / 29.0) / 7.787
    xyz = torch.where(fxyz > 0.2068966, power, scale)

    # For D65 white point
    xyz_ref_white = torch.tensor([0.95047, 1.0, 1.08883], device=xyz.device, dtype=xyz.dtype)[..., :, None, None]
    xyz_im = xyz * xyz_ref_white

    rgbs_im: torch.Tensor = xyz_to_rgb(xyz_im)

    # https://github.com/richzhang/colorization-pytorch/blob/66a1cb2e5258f7c8f374f582acc8b1ef99c13c27/util/util.py#L107
    #     rgbs_im = torch.where(rgbs_im < 0, torch.zeros_like(rgbs_im), rgbs_im)

    # Convert from RGB Linear to sRGB
    rgb_im = linear_rgb_to_rgb(rgbs_im)

    # Clip to 0,1 https://www.w3.org/Graphics/Color/srgb
    if clip:
        rgb_im = torch.clamp(rgb_im, min=0.0, max=1.0)

    return rgb_im

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial'''

    def __init__(self):
        self.reset()

    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # Size of photo

# %%
size = 32

# %% [markdown]
# # Device Configuration

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
test_path = 'images/test/'
test_transform = transforms.Compose([
    transforms.Resize((size, size)),  # can experiment
    transforms.ToTensor(),  # divide the pixel by 255
])

# %% [markdown]
# # Loading the data

# %%
test_dataset = torchvision.datasets.ImageFolder(root=test_path, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=350, shuffle=False)

# %% [markdown]
# # Convert RBG to LAB space

# %%
X = []  # array of tensors of  L
y = []  # array of tensors of A and B
X1 = []  # array of tensors of  L
y1 = []  # array of tensors of A and B
LAB1 = []
LAB = []
z = 0
for idx, (data, target) in enumerate(test_loader):
    for i in data:
#         print(z)
#         z = z + 1
        Lab = rgb_to_lab(i / (size-1))
        LAB1.append(Lab)
        X1.append(Lab[0])
        y1.append(Lab[1:3])
    LAB.append(LAB1)
    LAB1 = []
    X.append(X1)
    y.append(y1)
    X1 = []
    y1 = []

x = []
x1 = []
for batch in X:
    for i in batch:
        w = np.array(i)
        x1.append(torch.tensor(np.array([w])).unsqueeze(0))
#         print(torch.tensor(np.array([w])).shape)
    x.append(x1)
    x1 = []

print(len(x))
print(len(x[0]))
print(len(y))
print(len(y[0]))
# Out:
# 1
# 229
# 1
# 229

# %% [markdown]
# # Creating the model

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        resnet = models.resnet18(num_classes=365)
        # Change first conv layer to accept single-channel (grayscale) input
        resnet.conv1.weight = nn.Parameter(resnet.conv1.weight.sum(dim=1).unsqueeze(1))
        # Extract midlevel features from ResNet-gray
        self.midlevel_resnet = nn.Sequential(*list(resnet.children())[0:6])

        self.conv0 = nn.Conv2d(128, 1, 3, stride=1, padding=1)

        # The second model
        self.conv1 = nn.Conv2d(1, 64, 3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, stride=2, padding=1)
        self.conv4 = nn.Conv2d(128, 256, 3, stride=2, padding=1)
        self.pool = nn.MaxPool2d(2, 2)

        self.t_conv1 = nn.ConvTranspose2d(256, 128, 3, stride=2, padding=1, output_padding=1)
        self.t_conv2 = nn.ConvTranspose2d(128, 64, 3, stride=2, padding=1, output_padding=1)
        self.t_conv3 = nn.ConvTranspose2d(64, 32, 3, stride=2, padding=1, output_padding=1)
        self.t_conv4 = nn.ConvTranspose2d(32, 2, 3, stride=1, padding=1)

    def forward(self, x):
        x00 = self.midlevel_resnet(x)
        x0 = self.conv0(x00)
        x1 = F.relu(self.conv1(x0))
        x1 = F.pad(x1, (14, 14, 14, 14), "constant", 0)
        x2 = F.relu(self.conv2(x1))
        x3 = F.relu(self.conv3(x2))
        x4 = F.relu(self.conv4(x3))
        x5 = self.t_conv1(x4)
        x6 = self.t_conv2(x5)
        x7 = self.t_conv3(x6)
        x8 = self.t_conv4(x7)
        x8 = torch.tanh(x8)
        return x8

# %% [markdown]
# # Initialize the network

# %%
model = CNN().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.2)
# optimizer = optimizer = optim.Adam(model.parameters())
loss_func = torch.nn.MSELoss()
# losses = AverageMeter()
losses = []

# %%
def load_model(checkpoint):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])

# %%
load_model(torch.load("resnet.pth.tar"))
# Out:
# => Loading checkpoint

# %%
def ACCURACY_OF_ONE(A, B, Predicted_A, Predicted_B):
    print("=> Calculating the accuracy of models")
    accuracy_A = []
    accuracy_B = []
    for i in range(len(A)):
#         print(min(B[i]), max(B[i]))
        for j in range(len(A[i])):
            diff_A = abs(A[i][j] - Predicted_A[i][j])
            accuracy_A_p = 100 * ((2 - diff_A) / 2)
            diff_B = abs(B[i][j] - Predicted_B[i][j])
            accuracy_B_p = 100 * ((2 - diff_B) / 2)
            accuracy_A.append(accuracy_A_p)
            accuracy_B.append(accuracy_B_p)
    return ((sum(accuracy_A)/len(accuracy_A)) + (sum(accuracy_B)/len(accuracy_B)))/2

# %%
def ACCURACY_OF_MODEL():
    allAcc = []
    for i in range(0, 229):
        scores = model(x[0][i])
        acc = ACCURACY_OF_ONE(LAB[0][i][1], LAB[0][i][2], scores[0][0], scores[0][1])
        allAcc.append(acc)
        print(acc)
    return sum(allAcc)/len(allAcc)

# %%
ACCURACY_OF_MODEL()
# Out:
# => Calculating the accuracy of models
# tensor(89.0708, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(81.7025, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.7824, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(65.9416, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(79.3999, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.4221, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.7209, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.0054, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.2489, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.4399, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.9787, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.0246, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.3346, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.2310, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.8257, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.7704, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.6788, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.2605, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.2492, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.3147, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.6171, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.5448, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.8341, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(81.2961, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(83.4444, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.5463, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.1309, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.1510, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.7401, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.4322, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.1152, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.8431, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.8493, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.3044, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.1755, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.3556, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.7664, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.9259, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.0796, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(75.3960, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.3468, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.0494, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.5027, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.6541, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.8656, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.2941, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.6346, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.7020, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.9104, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.3552, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.5521, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.0736, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.2583, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.2650, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.8056, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.8232, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.3564, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.7720, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.2465, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.6928, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(75.2622, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.8168, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.5891, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.8467, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.4039, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(81.3147, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.1567, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.2653, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.4241, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.1399, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.1399, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.6640, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(82.7351, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(84.4344, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.7835, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.7109, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.0046, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.9789, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.9288, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.7347, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.5598, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.9036, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.3279, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.1496, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.7795, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.5952, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.9488, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.0782, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.1889, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.5538, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.4951, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.4113, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.0576, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.7482, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.7252, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.9328, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.8594, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.4775, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.5503, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.1910, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.8058, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.7648, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.5927, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.3629, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.2382, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.9326, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.1119, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.6134, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.0310, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.2985, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(78.1978, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.3680, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.0021, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.6024, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(83.1994, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.4586, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.0076, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.4629, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.6521, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.6146, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.3841, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.5803, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.7429, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.7270, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.4813, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(81.2351, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.2204, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.2188, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(84.8280, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.8887, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.0998, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.4456, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.5303, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(83.6203, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.9118, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.3359, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.0618, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.6038, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.2674, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(75.3374, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(75.9879, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.4229, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.9119, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.5910, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.6108, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.4967, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.5466, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.7048, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(82.7658, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.6011, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(81.3784, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(79.9462, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.7779, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.3108, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.9561, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(84.0024, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.9067, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.3479, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.6181, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.2407, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.2253, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.5013, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.2700, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.6578, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.5334, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.0254, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.6043, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.1686, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(82.0488, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.0110, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.5656, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.7773, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.7585, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.0313, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.0321, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(77.7355, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.9062, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.1983, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.2489, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.6067, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.0819, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.5788, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.6859, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(87.3942, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(65.9418, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.9906, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.4511, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.5537, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.1404, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.8636, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.6248, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.8770, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.4295, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.0989, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(97.3992, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.5609, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.6951, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(69.5131, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.4907, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.2921, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.1392, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(96.3580, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(86.8471, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.4024, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.4999, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.7153, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.1524, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.3875, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.4589, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.4119, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.2084, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(85.4388, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.5437, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(97.0994, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(90.3473, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(88.0274, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.4393, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.9485, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.0450, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(91.0209, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.4410, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(95.2734, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(84.0821, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.3488, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.5585, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(94.0061, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(93.5775, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(89.9967, grad_fn=<DivBackward0>)
# => Calculating the accuracy of models
# tensor(92.7013, grad_fn=<DivBackward0>)
# tensor(90.0960, grad_fn=<DivBackward0>)

# %%
# Showing picture 10
output = lab_to_rgb(LAB[0][10][0]*(size-1), LAB[0][10][1]*(size-1), LAB[0][10][2]*(size-1))
transform = T.ToPILImage()
img = transform(output)
img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x10B19C7C0>

# %%
# Showing the prediction of picture 10
prediction = model(x[0][10])
output2 = lab_to_rgb(LAB[0][10][0]*(size-1), prediction[0][0]*(size-1), prediction[0][1]*(size-1))
transform = T.ToPILImage()
img2 = transform(output2)
img2
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x10AF879D0>
